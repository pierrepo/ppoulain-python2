# %% [markdown]
# ## Numpy

# %%
import numpy as np
np.__version__
# Out:
# '2.4.2'

# %% [markdown]
# ## Pandas
#
# avec
# - xarray
# - openpyxl

# %%
import pandas as pd

# %%
import pyarrow

# %% [markdown]
# ## Scipy

# %%
import scipy

# %% [markdown]
# ## Statsmodels

# %%
import statsmodels

# %% [markdown]
# ## Matplotlib

# %%
import matplotlib

# %% [markdown]
# ## Biopython

# %%
import Bio

# %% [markdown]
# ## Linters et formaters

# %%
# !ruff --version
# Out:
# ruff 0.14.14

# %% [markdown]
# ## Informations de session
#
# Module [watermark](https://github.com/rasbt/watermark)

# %%
# %load_ext watermark
# %watermark --python --machine
# Show version for jupyterlab, imported packages and watermark itself
# %watermark --packages jupyterlab,ipywidgets --iversions --watermark
# Out:
# Python implementation: CPython
# Python version       : 3.13.11
# IPython version      : 9.9.0
#
# Compiler    : GCC 14.3.0
# OS          : Linux
# Release     : 6.14.0-37-generic
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 14
# Architecture: 64bit
#
# jupyterlab: 4.5.3
# ipywidgets: 8.1.8
#
# Bio        : 1.86
# matplotlib : 3.10.8
# numpy      : 2.4.2
# pandas     : 3.0.0
# pyarrow    : 23.0.0
# scipy      : 1.17.0
# statsmodels: 0.14.6
#
# Watermark: 2.6.0
